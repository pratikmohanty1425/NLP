# %% [markdown]
# **CSE4022 NATURAL LANGUAGE PROCESSING**
#
# **DIGITAL ASSIGNMENT 2**
#
# **Name - Pratik Mohanty**
#
# **Regno - 19BCE1100**

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('averaged_perceptron_tagger')
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %% [markdown]
# **Loading the corpora -**

# %%
with open('da2.txt') as f:
  corpora = f.read()

# %%
print(corpora)
# Out:
# Hello everyone. Myself Pratik mohanty, currently I’m perusing BTech computer science and engineering at VIT Chennai.I belong to a family of 4 me my mother father and big sister. I am from Baripada Odisha from east side of India. I have completed my +2 science from Sai International schools Bhubaneswar which is the one of the best school of Odisha. And passed my 10th from kendriya Vidyalaya baripada. After finishing my BTech I will be applying in different universities for master mostly I’m hoping to get selected in one of the universities of Europe. As per my most of the day spend through studding and playing games online, I also like to travel to different places. I like to do photography along with drawing as a hobby, I think I’m good at these sorts of works, also nor the less I like to keep up with recent news and technical aspects, love to code and have good at managing a team and working in a team. I am really a hard worker and a quick learner, I keep a interest in learning new stuffs and keep on try to do my best to reach my goal. In my collage life as its passed in the course of covid I have made many friends and most of the are really good. I have also been in the game development as the content creator position which was a fun and interesting work, I use my free time to work on different game on different platform by myself.

# %% [markdown]
# **Word Segmentation of the corpus -**

# %%
list_word=nltk.word_tokenize(corpora)
list_word
# Out:
# ['Hello',
#  'everyone',
#  '.',
#  'Myself',
#  'Pratik',
#  'mohanty',
#  ',',
#  'currently',
#  'I',
#  '’',
#  'm',
#  'perusing',
#  'BTech',
#  'computer',
#  'science',
#  'and',
#  'engineering',
#  'at',
#  'VIT',
#  'Chennai.I',
#  'belong',
#  'to',
#  'a',
#  'family',
#  'of',
#  '4',
#  'me',
#  'my',
#  'mother',
#  'father',
#  'and',
#  'big',
#  'sister',
#  '.',
#  'I',
#  'am',
#  'from',
#  'Baripada',
#  'Odisha',
#  'from',
#  'east',
#  'side',
#  'of',
#  'India',
#  '.',
#  'I',
#  'have',
#  'completed',
#  'my',
#  '+2',
#  'science',
#  'from',
#  'Sai',
#  'International',
#  'schools',
#  'Bhubaneswar',
#  'which',
#  'is',
#  'the',
#  'one',
#  'of',
#  'the',
#  'best',
#  'school',
#  'of',
#  'Odisha',
#  '.',
#  'And',
#  'passed',
#  'my',
#  '10th',
#  'from',
#  'kendriya',
#  'Vidyalaya',
#  'baripada',
#  '.',
#  'After',
#  'finishing',
#  'my',
#  'BTech',
#  'I',
#  'will',
#  'be',
#  'applying',
#  'in',
#  'different',
#  'universities',
#  'for',
#  'master',
#  'mostly',
#  'I',
#  '’',
#  'm',
#  'hoping',
#  'to',
#  'get',
#  'selected',
#  'in',
#  'one',
#  'of',
#  'the',
#  'universities',
#  'of',
#  'Europe',
#  '.',
#  'As',
#  'per',
#  'my',
#  'most',
#  'of',
#  'the',
#  'day',
#  'spend',
#  'through',
#  'studding',
#  'and',
#  'playing',
#  'games',
#  'online',
#  ',',
#  'I',
#  'also',
#  'like',
#  'to',
#  'travel',
#  'to',
#  'different',
#  'places',
#  '.',
#  'I',
#  'like',
#  'to',
#  'do',
#  'photography',
#  'along',
#  'with',
#  'drawing',
#  'as',
#  'a',
#  'hobby',
#  ',',
#  'I',
#  'think',
#  'I',
#  '’',
#  'm',
#  'good',
#  'at',
#  'these',
#  'sorts',
#  'of',
#  'works',
#  ',',
#  'also',
#  'nor',
#  'the',
#  'less',
#  'I',
#  'like',
#  'to',
#  'keep',
#  'up',
#  'with',
#  'recent',
#  'news',
#  'and',
#  'technical',
#  'aspects',
#  ',',
#  'love',
#  'to',
#  'code',
#  'and',
#  'have',
#  'good',
#  'at',
#  'managing',
#  'a',
#  'team',
#  'and',
#  'working',
#  'in',
#  'a',
#  'team',
#  '.',
#  'I',
#  'am',
#  'really',
#  'a',
#  'hard',
#  'worker',
#  'and',
#  'a',
#  'quick',
#  'learner',
#  ',',
#  'I',
#  'keep',
#  'a',
#  'interest',
#  'in',
#  'learning',
#  'new',
#  'stuffs',
#  'and',
#  'keep',
#  'on',
#  'try',
#  'to',
#  'do',
#  'my',
#  'best',
#  'to',
#  'reach',
#  'my',
#  'goal',
#  '.',
#  'In',
#  'my',
#  'collage',
#  'life',
#  'as',
#  'its',
#  'passed',
#  'in',
#  'the',
#  'course',
#  'of',
#  'covid',
#  'I',
#  'have',
#  'made',
#  'many',
#  'friends',
#  'and',
#  'most',
#  'of',
#  'the',
#  'are',
#  'really',
#  'good',
#  '.',
#  'I',
#  'have',
#  'also',
#  'been',
#  'in',
#  'the',
#  'game',
#  'development',
#  'as',
#  'the',
#  'content',
#  'creator',
#  'position',
#  'which',
#  'was',
#  'a',
#  'fun',
#  'and',
#  'interesting',
#  'work',
#  ',',
#  'I',
#  'use',
#  'my',
#  'free',
#  'time',
#  'to',
#  'work',
#  'on',
#  'different',
#  'game',
#  'on',
#  'different',
#  'platform',
#  'by',
#  'myself',
#  '.']

# %% [markdown]
# **Sentence segmentation of the corpus -**

# %%
list_sent=nltk.sent_tokenize(corpora)
list_sent
# Out:
# ['Hello everyone.',
#  'Myself Pratik mohanty, currently I’m perusing BTech computer science and engineering at VIT Chennai.I belong to a family of 4 me my mother father and big sister.',
#  'I am from Baripada Odisha from east side of India.',
#  'I have completed my +2 science from Sai International schools Bhubaneswar which is the one of the best school of Odisha.',
#  'And passed my 10th from kendriya Vidyalaya baripada.',
#  'After finishing my BTech I will be applying in different universities for master mostly I’m hoping to get selected in one of the universities of Europe.',
#  'As per my most of the day spend through studding and playing games online, I also like to travel to different places.',
#  'I like to do photography along with drawing as a hobby, I think I’m good at these sorts of works, also nor the less I like to keep up with recent news and technical aspects, love to code and have good at managing a team and working in a team.',
#  'I am really a hard worker and a quick learner, I keep a interest in learning new stuffs and keep on try to do my best to reach my goal.',
#  'In my collage life as its passed in the course of covid I have made many friends and most of the are really good.',
#  'I have also been in the game development as the content creator position which was a fun and interesting work, I use my free time to work on different game on different platform by myself.']

# %% [markdown]
# **Converting to the lower case -**

# %%
lowercase_words=[]
for sent in list_sent:
  for word in sent.split():
    lowercase_words.append(word.lower())

lowercase_words
# Out:
# ['hello',
#  'everyone.',
#  'myself',
#  'pratik',
#  'mohanty,',
#  'currently',
#  'i’m',
#  'perusing',
#  'btech',
#  'computer',
#  'science',
#  'and',
#  'engineering',
#  'at',
#  'vit',
#  'chennai.i',
#  'belong',
#  'to',
#  'a',
#  'family',
#  'of',
#  '4',
#  'me',
#  'my',
#  'mother',
#  'father',
#  'and',
#  'big',
#  'sister.',
#  'i',
#  'am',
#  'from',
#  'baripada',
#  'odisha',
#  'from',
#  'east',
#  'side',
#  'of',
#  'india.',
#  'i',
#  'have',
#  'completed',
#  'my',
#  '+2',
#  'science',
#  'from',
#  'sai',
#  'international',
#  'schools',
#  'bhubaneswar',
#  'which',
#  'is',
#  'the',
#  'one',
#  'of',
#  'the',
#  'best',
#  'school',
#  'of',
#  'odisha.',
#  'and',
#  'passed',
#  'my',
#  '10th',
#  'from',
#  'kendriya',
#  'vidyalaya',
#  'baripada.',
#  'after',
#  'finishing',
#  'my',
#  'btech',
#  'i',
#  'will',
#  'be',
#  'applying',
#  'in',
#  'different',
#  'universities',
#  'for',
#  'master',
#  'mostly',
#  'i’m',
#  'hoping',
#  'to',
#  'get',
#  'selected',
#  'in',
#  'one',
#  'of',
#  'the',
#  'universities',
#  'of',
#  'europe.',
#  'as',
#  'per',
#  'my',
#  'most',
#  'of',
#  'the',
#  'day',
#  'spend',
#  'through',
#  'studding',
#  'and',
#  'playing',
#  'games',
#  'online,',
#  'i',
#  'also',
#  'like',
#  'to',
#  'travel',
#  'to',
#  'different',
#  'places.',
#  'i',
#  'like',
#  'to',
#  'do',
#  'photography',
#  'along',
#  'with',
#  'drawing',
#  'as',
#  'a',
#  'hobby,',
#  'i',
#  'think',
#  'i’m',
#  'good',
#  'at',
#  'these',
#  'sorts',
#  'of',
#  'works,',
#  'also',
#  'nor',
#  'the',
#  'less',
#  'i',
#  'like',
#  'to',
#  'keep',
#  'up',
#  'with',
#  'recent',
#  'news',
#  'and',
#  'technical',
#  'aspects,',
#  'love',
#  'to',
#  'code',
#  'and',
#  'have',
#  'good',
#  'at',
#  'managing',
#  'a',
#  'team',
#  'and',
#  'working',
#  'in',
#  'a',
#  'team.',
#  'i',
#  'am',
#  'really',
#  'a',
#  'hard',
#  'worker',
#  'and',
#  'a',
#  'quick',
#  'learner,',
#  'i',
#  'keep',
#  'a',
#  'interest',
#  'in',
#  'learning',
#  'new',
#  'stuffs',
#  'and',
#  'keep',
#  'on',
#  'try',
#  'to',
#  'do',
#  'my',
#  'best',
#  'to',
#  'reach',
#  'my',
#  'goal.',
#  'in',
#  'my',
#  'collage',
#  'life',
#  'as',
#  'its',
#  'passed',
#  'in',
#  'the',
#  'course',
#  'of',
#  'covid',
#  'i',
#  'have',
#  'made',
#  'many',
#  'friends',
#  'and',
#  'most',
#  'of',
#  'the',
#  'are',
#  'really',
#  'good.',
#  'i',
#  'have',
#  'also',
#  'been',
#  'in',
#  'the',
#  'game',
#  'development',
#  'as',
#  'the',
#  'content',
#  'creator',
#  'position',
#  'which',
#  'was',
#  'a',
#  'fun',
#  'and',
#  'interesting',
#  'work,',
#  'i',
#  'use',
#  'my',
#  'free',
#  'time',
#  'to',
#  'work',
#  'on',
#  'different',
#  'game',
#  'on',
#  'different',
#  'platform',
#  'by',
#  'myself.']

# %% [markdown]
# **The number of words in the corpus -**

# %%
len(lowercase_words)
# Out:
# 255

# %% [markdown]
# **Removal of the Stop-words from the corpus -**

# %%
stop_words = set(stopwords.words('english'))
filtered_words=[]
for word in lowercase_words:
  if word not in stop_words:
    filtered_words.append(word)

filtered_words
# Out:
# ['hello',
#  'everyone.',
#  'pratik',
#  'mohanty,',
#  'currently',
#  'i’m',
#  'perusing',
#  'btech',
#  'computer',
#  'science',
#  'engineering',
#  'vit',
#  'chennai.i',
#  'belong',
#  'family',
#  '4',
#  'mother',
#  'father',
#  'big',
#  'sister.',
#  'baripada',
#  'odisha',
#  'east',
#  'side',
#  'india.',
#  'completed',
#  '+2',
#  'science',
#  'sai',
#  'international',
#  'schools',
#  'bhubaneswar',
#  'one',
#  'best',
#  'school',
#  'odisha.',
#  'passed',
#  '10th',
#  'kendriya',
#  'vidyalaya',
#  'baripada.',
#  'finishing',
#  'btech',
#  'applying',
#  'different',
#  'universities',
#  'master',
#  'mostly',
#  'i’m',
#  'hoping',
#  'get',
#  'selected',
#  'one',
#  'universities',
#  'europe.',
#  'per',
#  'day',
#  'spend',
#  'studding',
#  'playing',
#  'games',
#  'online,',
#  'also',
#  'like',
#  'travel',
#  'different',
#  'places.',
#  'like',
#  'photography',
#  'along',
#  'drawing',
#  'hobby,',
#  'think',
#  'i’m',
#  'good',
#  'sorts',
#  'works,',
#  'also',
#  'less',
#  'like',
#  'keep',
#  'recent',
#  'news',
#  'technical',
#  'aspects,',
#  'love',
#  'code',
#  'good',
#  'managing',
#  'team',
#  'working',
#  'team.',
#  'really',
#  'hard',
#  'worker',
#  'quick',
#  'learner,',
#  'keep',
#  'interest',
#  'learning',
#  'new',
#  'stuffs',
#  'keep',
#  'try',
#  'best',
#  'reach',
#  'goal.',
#  'collage',
#  'life',
#  'passed',
#  'course',
#  'covid',
#  'made',
#  'many',
#  'friends',
#  'really',
#  'good.',
#  'also',
#  'game',
#  'development',
#  'content',
#  'creator',
#  'position',
#  'fun',
#  'interesting',
#  'work,',
#  'use',
#  'free',
#  'time',
#  'work',
#  'different',
#  'game',
#  'different',
#  'platform',
#  'myself.']

# %% [markdown]
# **Count of words after Stop-words removal -**

# %%
len(filtered_words)
# Out:
# 135

# %% [markdown]
# **Stemming of the filtered list of words -**

# %%
ps = PorterStemmer()
for w in filtered_words:
  print(w," : ", ps.stem(w))
# Out:
# hello  :  hello
# everyone.  :  everyone.
# pratik  :  pratik
# mohanty,  :  mohanty,
# currently  :  current
# i’m  :  i’m
# perusing  :  perus
# btech  :  btech
# computer  :  comput
# science  :  scienc
# engineering  :  engin
# vit  :  vit
# chennai.i  :  chennai.i
# belong  :  belong
# family  :  famili
# 4  :  4
# mother  :  mother
# father  :  father
# big  :  big
# sister.  :  sister.
# baripada  :  baripada
# odisha  :  odisha
# east  :  east
# side  :  side
# india.  :  india.
# completed  :  complet
# +2  :  +2
# science  :  scienc
# sai  :  sai
# international  :  intern
# schools  :  school
# bhubaneswar  :  bhubaneswar
# one  :  one
# best  :  best
# school  :  school
# odisha.  :  odisha.
# passed  :  pass
# 10th  :  10th
# kendriya  :  kendriya
# vidyalaya  :  vidyalaya
# baripada.  :  baripada.
# finishing  :  finish
# btech  :  btech
# applying  :  appli
# different  :  differ
# universities  :  univers
# master  :  master
# mostly  :  mostli
# i’m  :  i’m
# hoping  :  hope
# get  :  get
# selected  :  select
# one  :  one
# universities  :  univers
# europe.  :  europe.
# per  :  per
# day  :  day
# spend  :  spend
# studding  :  stud
# playing  :  play
# games  :  game
# online,  :  online,
# also  :  also
# like  :  like
# travel  :  travel
# different  :  differ
# places.  :  places.
# like  :  like
# photography  :  photographi
# along  :  along
# drawing  :  draw
# hobby,  :  hobby,
# think  :  think
# i’m  :  i’m
# good  :  good
# sorts  :  sort
# works,  :  works,
# also  :  also
# less  :  less
# like  :  like
# keep  :  keep
# recent  :  recent
# news  :  news
# technical  :  technic
# aspects,  :  aspects,
# love  :  love
# code  :  code
# good  :  good
# managing  :  manag
# team  :  team
# working  :  work
# team.  :  team.
# really  :  realli
# hard  :  hard
# worker  :  worker
# quick  :  quick
# learner,  :  learner,
# keep  :  keep
# interest  :  interest
# learning  :  learn
# new  :  new
# stuffs  :  stuff
# keep  :  keep
# try  :  tri
# best  :  best
# reach  :  reach
# goal.  :  goal.
# collage  :  collag
# life  :  life
# passed  :  pass
# course  :  cours
# covid  :  covid
# made  :  made
# many  :  mani
# friends  :  friend
# really  :  realli
# good.  :  good.
# also  :  also
# game  :  game
# development  :  develop
# content  :  content
# creator  :  creator
# position  :  posit
# fun  :  fun
# interesting  :  interest
# work,  :  work,
# use  :  use
# free  :  free
# time  :  time
# work  :  work
# different  :  differ
# game  :  game
# different  :  differ
# platform  :  platform
# myself.  :  myself.

# %% [markdown]
# **Lemmatization of the filtered words -**

# %%
lemmatizer = WordNetLemmatizer()
for w in filtered_words:
  print(w," : ", lemmatizer.lemmatize(w))
# Out:
# hello  :  hello
# everyone.  :  everyone.
# pratik  :  pratik
# mohanty,  :  mohanty,
# currently  :  currently
# i’m  :  i’m
# perusing  :  perusing
# btech  :  btech
# computer  :  computer
# science  :  science
# engineering  :  engineering
# vit  :  vit
# chennai.i  :  chennai.i
# belong  :  belong
# family  :  family
# 4  :  4
# mother  :  mother
# father  :  father
# big  :  big
# sister.  :  sister.
# baripada  :  baripada
# odisha  :  odisha
# east  :  east
# side  :  side
# india.  :  india.
# completed  :  completed
# +2  :  +2
# science  :  science
# sai  :  sai
# international  :  international
# schools  :  school
# bhubaneswar  :  bhubaneswar
# one  :  one
# best  :  best
# school  :  school
# odisha.  :  odisha.
# passed  :  passed
# 10th  :  10th
# kendriya  :  kendriya
# vidyalaya  :  vidyalaya
# baripada.  :  baripada.
# finishing  :  finishing
# btech  :  btech
# applying  :  applying
# different  :  different
# universities  :  university
# master  :  master
# mostly  :  mostly
# i’m  :  i’m
# hoping  :  hoping
# get  :  get
# selected  :  selected
# one  :  one
# universities  :  university
# europe.  :  europe.
# per  :  per
# day  :  day
# spend  :  spend
# studding  :  studding
# playing  :  playing
# games  :  game
# online,  :  online,
# also  :  also
# like  :  like
# travel  :  travel
# different  :  different
# places.  :  places.
# like  :  like
# photography  :  photography
# along  :  along
# drawing  :  drawing
# hobby,  :  hobby,
# think  :  think
# i’m  :  i’m
# good  :  good
# sorts  :  sort
# works,  :  works,
# also  :  also
# less  :  le
# like  :  like
# keep  :  keep
# recent  :  recent
# news  :  news
# technical  :  technical
# aspects,  :  aspects,
# love  :  love
# code  :  code
# good  :  good
# managing  :  managing
# team  :  team
# working  :  working
# team.  :  team.
# really  :  really
# hard  :  hard
# worker  :  worker
# quick  :  quick
# learner,  :  learner,
# keep  :  keep
# interest  :  interest
# learning  :  learning
# new  :  new
# stuffs  :  stuff
# keep  :  keep
# try  :  try
# best  :  best
# reach  :  reach
# goal.  :  goal.
# collage  :  collage
# life  :  life
# passed  :  passed
# course  :  course
# covid  :  covid
# made  :  made
# many  :  many
# friends  :  friend
# really  :  really
# good.  :  good.
# also  :  also
# game  :  game
# development  :  development
# content  :  content
# creator  :  creator
# position  :  position
# fun  :  fun
# interesting  :  interesting
# work,  :  work,
# use  :  use
# free  :  free
# time  :  time
# work  :  work
# different  :  different
# game  :  game
# different  :  different
# platform  :  platform
# myself.  :  myself.

# %% [markdown]
# **Part of speech tagging of the filtered-words -**

# %%
nltk.pos_tag(filtered_words)
# Out:
# [('hello', 'NN'),
#  ('everyone.', 'NN'),
#  ('pratik', 'NN'),
#  ('mohanty,', 'VBZ'),
#  ('currently', 'RB'),
#  ('i’m', 'JJ'),
#  ('perusing', 'VBG'),
#  ('btech', 'NN'),
#  ('computer', 'NN'),
#  ('science', 'NN'),
#  ('engineering', 'NN'),
#  ('vit', 'NN'),
#  ('chennai.i', 'NN'),
#  ('belong', 'IN'),
#  ('family', 'NN'),
#  ('4', 'CD'),
#  ('mother', 'NN'),
#  ('father', 'NN'),
#  ('big', 'JJ'),
#  ('sister.', 'NN'),
#  ('baripada', 'NN'),
#  ('odisha', 'IN'),
#  ('east', 'JJ'),
#  ('side', 'NN'),
#  ('india.', 'NN'),
#  ('completed', 'VBD'),
#  ('+2', 'JJ'),
#  ('science', 'NN'),
#  ('sai', 'VBD'),
#  ('international', 'JJ'),
#  ('schools', 'NNS'),
#  ('bhubaneswar', 'VBP'),
#  ('one', 'CD'),
#  ('best', 'JJS'),
#  ('school', 'NN'),
#  ('odisha.', 'NN'),
#  ('passed', 'VBD'),
#  ('10th', 'CD'),
#  ('kendriya', 'NN'),
#  ('vidyalaya', 'NN'),
#  ('baripada.', 'NN'),
#  ('finishing', 'VBG'),
#  ('btech', 'JJ'),
#  ('applying', 'VBG'),
#  ('different', 'JJ'),
#  ('universities', 'NNS'),
#  ('master', 'RBR'),
#  ('mostly', 'RB'),
#  ('i’m', 'JJ'),
#  ('hoping', 'VBG'),
#  ('get', 'NN'),
#  ('selected', 'VBN'),
#  ('one', 'CD'),
#  ('universities', 'NNS'),
#  ('europe.', 'VBP'),
#  ('per', 'IN'),
#  ('day', 'NN'),
#  ('spend', 'VBP'),
#  ('studding', 'VBG'),
#  ('playing', 'VBG'),
#  ('games', 'NNS'),
#  ('online,', 'RB'),
#  ('also', 'RB'),
#  ('like', 'VBP'),
#  ('travel', 'JJ'),
#  ('different', 'JJ'),
#  ('places.', 'NNS'),
#  ('like', 'IN'),
#  ('photography', 'NN'),
#  ('along', 'IN'),
#  ('drawing', 'VBG'),
#  ('hobby,', 'NN'),
#  ('think', 'VBP'),
#  ('i’m', 'RB'),
#  ('good', 'JJ'),
#  ('sorts', 'NNS'),
#  ('works,', 'NN'),
#  ('also', 'RB'),
#  ('less', 'RBR'),
#  ('like', 'IN'),
#  ('keep', 'VB'),
#  ('recent', 'JJ'),
#  ('news', 'NN'),
#  ('technical', 'JJ'),
#  ('aspects,', 'NN'),
#  ('love', 'NN'),
#  ('code', 'NN'),
#  ('good', 'JJ'),
#  ('managing', 'NN'),
#  ('team', 'NN'),
#  ('working', 'VBG'),
#  ('team.', 'NNS'),
#  ('really', 'RB'),
#  ('hard', 'JJ'),
#  ('worker', 'NN'),
#  ('quick', 'NN'),
#  ('learner,', 'NN'),
#  ('keep', 'VB'),
#  ('interest', 'NN'),
#  ('learning', 'VBG'),
#  ('new', 'JJ'),
#  ('stuffs', 'NNS'),
#  ('keep', 'VBP'),
#  ('try', 'NN'),
#  ('best', 'JJS'),
#  ('reach', 'NN'),
#  ('goal.', 'NN'),
#  ('collage', 'NN'),
#  ('life', 'NN'),
#  ('passed', 'VBD'),
#  ('course', 'NN'),
#  ('covid', 'NN'),
#  ('made', 'VBD'),
#  ('many', 'JJ'),
#  ('friends', 'NNS'),
#  ('really', 'RB'),
#  ('good.', 'NNS'),
#  ('also', 'RB'),
#  ('game', 'NN'),
#  ('development', 'NN'),
#  ('content', 'NN'),
#  ('creator', 'NN'),
#  ('position', 'NN'),
#  ('fun', 'NN'),
#  ('interesting', 'VBG'),
#  ('work,', 'NN'),
#  ('use', 'NN'),
#  ('free', 'JJ'),
#  ('time', 'NN'),
#  ('work', 'NN'),
#  ('different', 'JJ'),
#  ('game', 'NN'),
#  ('different', 'JJ'),
#  ('platform', 'NN'),
#  ('myself.', 'NN')]

# %% [markdown]
# **Part of Speech tagging for the list of all the words -**

# %%
nltk.pos_tag(list_word)
# Out:
# [('Hello', 'NNP'),
#  ('everyone', 'NN'),
#  ('.', '.'),
#  ('Myself', 'PRP'),
#  ('Pratik', 'NNP'),
#  ('mohanty', 'NN'),
#  (',', ','),
#  ('currently', 'RB'),
#  ('I', 'PRP'),
#  ('’', 'VBP'),
#  ('m', 'JJ'),
#  ('perusing', 'NN'),
#  ('BTech', 'NNP'),
#  ('computer', 'NN'),
#  ('science', 'NN'),
#  ('and', 'CC'),
#  ('engineering', 'NN'),
#  ('at', 'IN'),
#  ('VIT', 'NNP'),
#  ('Chennai.I', 'NNP'),
#  ('belong', 'NN'),
#  ('to', 'TO'),
#  ('a', 'DT'),
#  ('family', 'NN'),
#  ('of', 'IN'),
#  ('4', 'CD'),
#  ('me', 'PRP'),
#  ('my', 'PRP$'),
#  ('mother', 'NN'),
#  ('father', 'NN'),
#  ('and', 'CC'),
#  ('big', 'JJ'),
#  ('sister', 'NN'),
#  ('.', '.'),
#  ('I', 'PRP'),
#  ('am', 'VBP'),
#  ('from', 'IN'),
#  ('Baripada', 'NNP'),
#  ('Odisha', 'NNP'),
#  ('from', 'IN'),
#  ('east', 'JJ'),
#  ('side', 'NN'),
#  ('of', 'IN'),
#  ('India', 'NNP'),
#  ('.', '.'),
#  ('I', 'PRP'),
#  ('have', 'VBP'),
#  ('completed', 'VBN'),
#  ('my', 'PRP$'),
#  ('+2', 'JJ'),
#  ('science', 'NN'),
#  ('from', 'IN'),
#  ('Sai', 'NNP'),
#  ('International', 'NNP'),
#  ('schools', 'NNS'),
#  ('Bhubaneswar', 'NNP'),
#  ('which', 'WDT'),
#  ('is', 'VBZ'),
#  ('the', 'DT'),
#  ('one', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('best', 'JJS'),
#  ('school', 'NN'),
#  ('of', 'IN'),
#  ('Odisha', 'NNP'),
#  ('.', '.'),
#  ('And', 'CC'),
#  ('passed', 'VBD'),
#  ('my', 'PRP$'),
#  ('10th', 'CD'),
#  ('from', 'IN'),
#  ('kendriya', 'NN'),
#  ('Vidyalaya', 'NNP'),
#  ('baripada', 'NN'),
#  ('.', '.'),
#  ('After', 'IN'),
#  ('finishing', 'VBG'),
#  ('my', 'PRP$'),
#  ('BTech', 'NN'),
#  ('I', 'PRP'),
#  ('will', 'MD'),
#  ('be', 'VB'),
#  ('applying', 'VBG'),
#  ('in', 'IN'),
#  ('different', 'JJ'),
#  ('universities', 'NNS'),
#  ('for', 'IN'),
#  ('master', 'NN'),
#  ('mostly', 'RB'),
#  ('I', 'PRP'),
#  ('’', 'VBP'),
#  ('m', 'RB'),
#  ('hoping', 'VBG'),
#  ('to', 'TO'),
#  ('get', 'VB'),
#  ('selected', 'VBN'),
#  ('in', 'IN'),
#  ('one', 'CD'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('universities', 'NNS'),
#  ('of', 'IN'),
#  ('Europe', 'NNP'),
#  ('.', '.'),
#  ('As', 'IN'),
#  ('per', 'IN'),
#  ('my', 'PRP$'),
#  ('most', 'JJS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('day', 'NN'),
#  ('spend', 'VBP'),
#  ('through', 'IN'),
#  ('studding', 'NN'),
#  ('and', 'CC'),
#  ('playing', 'VBG'),
#  ('games', 'NNS'),
#  ('online', 'JJ'),
#  (',', ','),
#  ('I', 'PRP'),
#  ('also', 'RB'),
#  ('like', 'VBP'),
#  ('to', 'TO'),
#  ('travel', 'VB'),
#  ('to', 'TO'),
#  ('different', 'JJ'),
#  ('places', 'NNS'),
#  ('.', '.'),
#  ('I', 'PRP'),
#  ('like', 'VBP'),
#  ('to', 'TO'),
#  ('do', 'VB'),
#  ('photography', 'VB'),
#  ('along', 'IN'),
#  ('with', 'IN'),
#  ('drawing', 'NN'),
#  ('as', 'IN'),
#  ('a', 'DT'),
#  ('hobby', 'NN'),
#  (',', ','),
#  ('I', 'PRP'),
#  ('think', 'VBP'),
#  ('I', 'PRP'),
#  ('’', 'VBP'),
#  ('m', 'RB'),
#  ('good', 'JJ'),
#  ('at', 'IN'),
#  ('these', 'DT'),
#  ('sorts', 'NNS'),
#  ('of', 'IN'),
#  ('works', 'NNS'),
#  (',', ','),
#  ('also', 'RB'),
#  ('nor', 'CC'),
#  ('the', 'DT'),
#  ('less', 'JJR'),
#  ('I', 'PRP'),
#  ('like', 'VBP'),
#  ('to', 'TO'),
#  ('keep', 'VB'),
#  ('up', 'RP'),
#  ('with', 'IN'),
#  ('recent', 'JJ'),
#  ('news', 'NN'),
#  ('and', 'CC'),
#  ('technical', 'JJ'),
#  ('aspects', 'NNS'),
#  (',', ','),
#  ('love', 'NN'),
#  ('to', 'TO'),
#  ('code', 'NN'),
#  ('and', 'CC'),
#  ('have', 'VBP'),
#  ('good', 'VBN'),
#  ('at', 'IN'),
#  ('managing', 'VBG'),
#  ('a', 'DT'),
#  ('team', 'NN'),
#  ('and', 'CC'),
#  ('working', 'VBG'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('team', 'NN'),
#  ('.', '.'),
#  ('I', 'PRP'),
#  ('am', 'VBP'),
#  ('really', 'RB'),
#  ('a', 'DT'),
#  ('hard', 'JJ'),
#  ('worker', 'NN'),
#  ('and', 'CC'),
#  ('a', 'DT'),
#  ('quick', 'JJ'),
#  ('learner', 'NN'),
#  (',', ','),
#  ('I', 'PRP'),
#  ('keep', 'VBP'),
#  ('a', 'DT'),
#  ('interest', 'NN'),
#  ('in', 'IN'),
#  ('learning', 'VBG'),
#  ('new', 'JJ'),
#  ('stuffs', 'NNS'),
#  ('and', 'CC'),
#  ('keep', 'VB'),
#  ('on', 'IN'),
#  ('try', 'NN'),
#  ('to', 'TO'),
#  ('do', 'VB'),
#  ('my', 'PRP$'),
#  ('best', 'JJS'),
#  ('to', 'TO'),
#  ('reach', 'VB'),
#  ('my', 'PRP$'),
#  ('goal', 'NN'),
#  ('.', '.'),
#  ('In', 'IN'),
#  ('my', 'PRP$'),
#  ('collage', 'NN'),
#  ('life', 'NN'),
#  ('as', 'IN'),
#  ('its', 'PRP$'),
#  ('passed', 'VBN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('course', 'NN'),
#  ('of', 'IN'),
#  ('covid', 'NN'),
#  ('I', 'PRP'),
#  ('have', 'VBP'),
#  ('made', 'VBN'),
#  ('many', 'JJ'),
#  ('friends', 'NNS'),
#  ('and', 'CC'),
#  ('most', 'JJS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('are', 'VBP'),
#  ('really', 'RB'),
#  ('good', 'JJ'),
#  ('.', '.'),
#  ('I', 'PRP'),
#  ('have', 'VBP'),
#  ('also', 'RB'),
#  ('been', 'VBN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('game', 'NN'),
#  ('development', 'NN'),
#  ('as', 'IN'),
#  ('the', 'DT'),
#  ('content', 'NN'),
#  ('creator', 'NN'),
#  ('position', 'NN'),
#  ('which', 'WDT'),
#  ('was', 'VBD'),
#  ('a', 'DT'),
#  ('fun', 'NN'),
#  ('and', 'CC'),
#  ('interesting', 'JJ'),
#  ('work', 'NN'),
#  (',', ','),
#  ('I', 'PRP'),
#  ('use', 'VBP'),
#  ('my', 'PRP$'),
#  ('free', 'JJ'),
#  ('time', 'NN'),
#  ('to', 'TO'),
#  ('work', 'VB'),
#  ('on', 'IN'),
#  ('different', 'JJ'),
#  ('game', 'NN'),
#  ('on', 'IN'),
#  ('different', 'JJ'),
#  ('platform', 'NN'),
#  ('by', 'IN'),
#  ('myself', 'PRP'),
#  ('.', '.')]
